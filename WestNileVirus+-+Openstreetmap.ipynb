# %%
import geopandas as gpd
from os import listdir
import time
import pandas as pd
from shapely.geometry import Point, Polygon, MultiPolygon, LinearRing
import numpy as np

# %%
# Function definitions

# Function "log" makes a log with the added string, and mark it with the current time
def log(s):
    print('[' + time.strftime('%a %H:%M:%S') + '] ' + s)

# %%
osmDir = 'C:/Users/kasina/Dropbox/Python tutorial/West Nile virus/map'

#put the shp filenames into a list
shapeFiles = [f for f in listdir(osmDir) if f.endswith('.shp')] 

#the 2nd and 3rd part of the name is the type of the shape file, let's put them into a list
shapeTypes = [(i.split("_")[3]) for i in shapeFiles] 

# Create a cellShapes GeoPandas DataFrame with reading all the cellshape files
cellShapes = None

log("Start reading shape files...")
for i in range(len(shapeFiles)):
    tmp = gpd.read_file(osmDir+"\\"+shapeFiles[i]) #if we use Lynux, we should use "/" instead of "\\"
    tmp['Shape_Type'] = shapeTypes[i]
    if cellShapes is not None:
        cellShapes = cellShapes.append(tmp)
    else:
        cellShapes = tmp
log("Finished reading shape files...")

cellShapes.head()
# Out:
# [Sat 16:37:09] Start reading shape files...
# [Sat 16:47:36] Finished reading shape files...
#   Shape_Type access addr:city addr:inclu addr:postc addr:stree  admin_leve  \
# 0  admin.shp    NaN       NaN        NaN        NaN        NaN         8.0
# 1  admin.shp    NaN       NaN        NaN        NaN        NaN         8.0
# 2  admin.shp    NaN       NaN        NaN        NaN        NaN         8.0
# 3  admin.shp    NaN       NaN        NaN        NaN        NaN         NaN
# 4  admin.shp    NaN       NaN        NaN        NaN        NaN         8.0
#
#    area  bridge class   ...     id              name oneway    osm_id  \
# 0   NaN     NaN   NaN   ...    1.0  Merrionette Park    NaN -122049.0
# 1   NaN     NaN   NaN   ...    2.0    Evergreen Park    NaN -122050.0
# 2   NaN     NaN   NaN   ...    3.0     Schiller Park    NaN -122051.0
# 3   NaN     NaN   NaN   ...    4.0   Preston Heights    NaN -122033.0
# 4   NaN     NaN   NaN   ...    5.0       Lincolnwood    NaN -122052.0
#
# ...

# %%
print(cellShapes.geometry.type.value_counts())
# Out:
# Polygon               953345
# LineString            411016
# Point                  56170
# MultiPolygon             224
# GeometryCollection         2
# dtype: int64

# %%
cellShapes1 = cellShapes[cellShapes.geometry.type == 'Polygon']

# %%
print(cellShapes1.geometry.type.value_counts())
# Out:
# Polygon    953345
# dtype: int64

# %%
cellShapes1.reset_index(drop=True, inplace=True)
cellShapes1
# Out:
#             Shape_Type access addr:city addr:inclu addr:postc addr:stree  \
# 0            admin.shp    NaN       NaN        NaN        NaN        NaN
# 1            admin.shp    NaN       NaN        NaN        NaN        NaN
# 2            admin.shp    NaN       NaN        NaN        NaN        NaN
# 3            admin.shp    NaN       NaN        NaN        NaN        NaN
# 4            admin.shp    NaN       NaN        NaN        NaN        NaN
# 5            admin.shp    NaN       NaN        NaN        NaN        NaN
# 6            admin.shp    NaN       NaN        NaN        NaN        NaN
# 7            admin.shp    NaN       NaN        NaN        NaN        NaN
# 8            admin.shp    NaN       NaN        NaN        NaN        NaN
# 9            admin.shp    NaN       NaN        NaN        NaN        NaN
# 10           admin.shp    NaN       NaN        NaN        NaN        NaN
# 11           admin.shp    NaN       NaN        NaN        NaN        NaN
# ...

# %%
train = pd.read_csv('C:/Users/kasina/Dropbox/Python tutorial/West Nile virus/train.csv')
train['lat-long'] = train.apply(lambda row: Point(row['Latitude'], row['Longitude']),axis=1)

# %%
train['shape_type'] = np.nan
train['location_type'] = np.nan

# %%
log("Start")
for i in range(len(train_ex)):
    for j in range(len(cellShapes1_ex)):
        if cellShapes1_ex['geometry'][j].contains(train_ex['lat-long'][i]):
            train_ex['shape_type'][i] = cellShapes1_ex['Shape_Type'][j]
            train_ex['location_type'][i] = cellShapes1_ex['type'][j]
        else:
            train_ex['shape_type'][i] = 'unknown'
            train_ex['location_type'][i] = 'unknown'
log("Finish")
# Out:
# [Sat 23:12:53] Start
# C:\Users\kasina\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kasina\Anaconda2\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# [Sat 23:13:38] Finish

# %%
log("Start")
for i in range(len(train)):
    for j in range(len(cellShapes1)):
        if cellShapes1['geometry'][j].contains(train['lat-long'][i]):
            train['shape_type'][i] = cellShapes1['Shape_Type'][j]
            train['location_type'][i] = cellShapes1['type'][j]
        else:
            train['shape_type'][i] = 'unknown'
            train['location_type'][i] = 'unknown' 
log("Finish")
# Out:
# [Sat 23:14:24] Start
# C:\Users\kasina\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kasina\Anaconda2\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# Exception KeyboardInterrupt in 'zmq.backend.cython.message.Frame.__dealloc__' ignored
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-221-ec0c55635bd7> in <module>()
#       6             train['location_type'][i] = cellShapes1['type'][j]
#       7         else:
# ----> 8             train['shape_type'][i] = 'unknown'
# ...

# %%
train
# Out:
#              Date                                            Address  \
# 0      2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1      2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2      2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3      2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4      2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 5      2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA
# 6      2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA
# 7      2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 8      2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 9      2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA
# 10     2007-05-29    2100 North Stave Street, Chicago, IL 60647, USA
# 11     2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# 12     2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# ...
